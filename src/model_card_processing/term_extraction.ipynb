# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import pandas as pd
import ast
from tqdm import tqdm
from src.models.llm import call
from src.models.utils import *
from src.models.config import get_model_config

term_lst = []

# %%
# model = 'llama3_8b'
# def llm_config_func(llm):
#     llm.temperature = 0
#     llm.max_tokens = 4096
#     return llm
# config = get_model_config(model)

### llama2 7b
# model = 'llama2_7b'
# def llm_config_func(llm):
#     llm.temperature = 0
#     llm.max_tokens = 2048
#     return llm
# config = get_model_config(model)

## gpt3.5
model = 'gpt-3.5-turbo'
def llm_config_func(llm):
    llm.temperature = 0.8
    llm.max_tokens = 4096
    return llm
config = get_model_config(model)

# %%
import os
import re

mc_file_paths = []
for filename in os.listdir("./data_model_cards/claude3"):
    mc_file_paths.append("./data_model_cards/claude3/"+filename)

f = open(mc_file_paths[2], "r")
mc_text = f.read()

mc_sentences = re.findall(r"[^.!?]+", re.sub(r"\n+", ".", mc_text))

# %%
# extracting scientific jargon from English model cards

for sent in mc_sentences:
    prompt = [
        """You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
            Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text. 
            An example of a response is: [artificial intelligence, machine learning]. 
            If you don't find any scientific jargon or terminology respond as follows: []""",
            
        """The following text is:
        "{text}"
        """.format(text=sent)
    ]

    res = call(
        prompt,
        llm_config_func,
        has_system_prompt=True,
        model_version=model,
        verbose=True,
        listOutput=True,
        **config
    )

    term_lst += res

# post-processing list
term_lst = list(set(map(lambda x: x.replace("[", "").replace("]",""), term_lst)))
if "" in term_lst:
    term_lst.remove("")
# Out:
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "# Model Card for microsoft/git-base-textvqa"
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "The microsoft/git-base-textvqa model is a generative image-to-text transformer (GIT) that unifies vision-language tasks such as visual question answering (VQA)"
#
# ['[generative', 'transformer', 'vision-language', 'visual question answering (VQA)]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " It achieves state-of-the-art performance on various VQA benchmarks by interpreting the question as a caption prefix and generating the answer directly, without pre-defined candidate answers"
#
# ['[state-of-the-art performance', 'VQA benchmarks', 'caption prefix', 'pre-defined candidate answers]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "## Model Details"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "### Model Description"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "Model Architecture:"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "The model consists of an image encoder and a text decoder in a transformer architecture"
#
# ['[encoder', 'decoder', 'transformer architecture]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " The image encoder is based on a contrastive pre-trained model that takes a raw image as input and outputs a compact 2D feature map, which is flattened and projected to D dimensions"
#
# ['[contrastive', 'pre-trained model', 'feature map', 'flattened', 'projected]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " The text is tokenized, embedded into D dimensions, and concatenated with the image features as input to the transformer module"
#
# ['[tokenized', 'embedded', 'dimensions', 'concatenated', 'image features', 'transformer module]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " The text is decoded auto-regressively until the [EOS] token or maximum steps are reached"
#
# ['[auto-regressively', 'EOS', 'token]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "Training Procedures:"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "The model is pre-trained on large-scale image-text paired data with a language modeling objective to generate the associated text description given an input image"
#
# ['[pre-trained', 'large-scale', 'image-text paired data', 'language modeling objective', 'generate', 'associated text description', 'input image]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " For fine-tuning on visual question answering tasks like TextVQA, the question and ground-truth answer are concatenated as a special caption, with the language modeling loss only applied to the answer and [EOS] tokens"
#
# ['[visual question answering', 'TextVQA', 'language modeling loss', 'EOS]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " The model learns to predict the answer in a generative manner without pre-defined candidate answers"
#
# ['[generative', 'pre-defined candidate answers]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "Parameters:"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "[More Information Needed]"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "Important Disclaimers:"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- The model is a generative approach to visual question answering, which imposes more challenges compared to discriminative methods that use pre-defined answer candidates"
#
# ['[generative approach', 'visual question answering', 'discriminative methods', 'pre-defined answer candidates]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " Due to the difficulty of the generative task, the model may have slightly worse performance on some VQA benchmarks compared to discriminative approaches"
#
# ['[generative task', 'VQA benchmarks', 'discriminative approaches]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- [More Information Needed]"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "For model card updates or further information, please contact the project organizer of the microsoft/git-base-textvqa development team"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- **Developed by:** Jianfeng Wang; Zhengyuan Yang; Xiaowei Hu; Linjie Li; Kevin Lin; Zicheng Liu; Ce Liu; Lijuan Wang"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- **Funded by:** Based on the provided references, the model microsoft/git-base-textvqa appears to be funded by Microsoft"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " This can be inferred from a few key points:"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "1"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " The model name itself includes "microsoft", indicating it is a Microsoft project"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "2"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " Reference 4 mentions Microsoft trademarks and logos, further suggesting this is a Microsoft project"
#
# ['[reference', 'trademarks', 'logos', 'project]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " "
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "3"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " Reference 5 mentions this project has adopted the Microsoft Open Source Code of Conduct"
#
# ['[Open Source', 'Code of Conduct', 'Microsoft]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "4"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " Many of the authors listed in Reference 3 seem to be Microsoft affiliated based on their email contact in Reference 5 (opencode@microsoft"
#
# ['[Reference 3', 'Reference 5', 'opencode@microsoft]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "com)"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "However, to say definitively that Microsoft is the sole funder, [More Information Needed]"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " The references do not explicitly state all funding sources"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " It's possible there are other funding sources not mentioned here"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " But Microsoft's involvement and likely funding seems clear based on the available information"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- **Shared by:** Based on the references provided, the contributors who made the model microsoft/git-base-textvqa available online as a GitHub repo are:"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "Jianfeng Wang, Zhengyuan Yang, Xiaowei Hu, Linjie Li, Kevin Lin, Zicheng Liu, Ce Liu, and Lijuan Wang"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "The references do not provide complete information about the specific roles and contributions of each individual in making the model available on GitHub"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " [More Information Needed] on those details"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- **Model type:** The microsoft/git-base-textvqa model is a generative image-to-text model that uses a language modeling loss for fine-tuning on the visual question answering task, with an image encoder and text decoder architecture trained on image-text pairs"
#
# ['[generative', 'language modeling', 'fine-tuning', 'visual question answering', 'image encoder', 'text decoder', 'image-text pairs]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- **Language(s):** The model microsoft/git-base-textvqa processes natural language text descriptions associated with input images, based on being pre-trained on large-scale image-text pairs"
#
# ['[pre-trained', 'large-scale image-text pairs]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- **License:** [More Information Needed]"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "The provided references do not contain any information about the specific license being used for the microsoft/git-base-textvqa model"
#
# ['[license', 'microsoft/git-base-textvqa model]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " More details would be needed from the model developers or documentation to determine the license under which this model is being released"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- **Finetuned from model:** The model microsoft/git-base-textvqa is fine-tuned from a base model initialized from contrastive pretraining, as mentioned in Reference 2:"
#
# ['[Finetuned', 'microsoft/git-base-textvqa', 'contrastive pretraining]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         ""In our design, the image encoder is initialized from the contrastive pretraining"
#
# ['[contrastive pretraining]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         """
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "However, the specific name and link to the base contrastive pretraining model is not provided in the given references"
#
# ['[contrastive pretraining model]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " [More Information Needed] on the exact base model used for initialization"
#
# ['[base model', 'initialization]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "### Model Sources"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- **Repository:** https://github"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "com/microsoft/GenerativeImage2Text"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "- **Paper:** https://arxiv"
#
# ...
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "```"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "[More Information Needed] on the exact compute resources like number of GPUs, memory, etc"
#
# ['[compute resources', 'GPUs', 'memory]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         " used for training the base model"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "## Citation"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "```"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "@misc{jianfeng-git,"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "    author = {Jianfeng Wang and"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "              Zhengyuan Yang and"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "              Xiaowei Hu and"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "              Linjie Li and"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "              Kevin Lin and"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "              Zicheng Liu and"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "              Ce Liu and"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "              Lijuan Wang},"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "    title  = {GIT: A Generative Image-to-text Transformer for Vision and Language},"
#
# ['[Generative Image-to-text Transformer]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "    url    = {https://arxiv"
#
# ['[arXiv]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "org/pdf/2205"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "14100"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "pdf}"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "}"
#
# ['[]']
# 1
# org-q4KwOHTjWKGwZDHrQlsOPcp3
# You are a language expert with a focus on machine translation. Your task is to analyze the following model card and identify scientific jargon or terminology within the field of machine learning that might be challenging for machine translation software to accurately translate to Chinese, Russian, Japanese, French, and Arabic.
#             Respond in the following format (as a list): [Term 1, Term 2, Term 3, ...] Respond only as shown, with no additional discursive or explanatory text.
#             An example of a response is: [artificial intelligence, machine learning].
#             If you don't find any scientific jargon or terminology respond as follows: []
# The following text is:
#         "```"
#
# ['[]']

# %%
with open('scientific_jargon_lst.txt', 'w') as f:
    for term in term_lst:
        f.write(f"{term}\n")

term_lst
# Out:
# ['integration',
#  'training epochs',
#  'pre-training',
#  'COCO images',
#  'OCR-VQA',
#  'RoBERTa text encoder',
#  'generation-based classification approach',
#  'Cloud Provider',
#  'captioning',
#  'maskrcnn-benchmark',
#  'capacity',
#  'bias',
#  'misuse',
#  'generativeimage2text',
#  'Code of Conduct',
#  'training',
#  'pixels',
#  'Azure',
#  'MSRVTT-QA',
#  'post-processing',
#  'error types',
#  'MSVD-QA',
#  'qualitative analysis',
#  'generative task',
#  'performance characteristics',
#  'linear layer',
#  'evaluation benchmarks',
#  'concatenated image features',
#  'ethical concerns',
#  'Mishra et al',
#  'NPD',
#  'TextVQA',
#  'Ref 2',
#  'tokenization',
#  'CLIP',
#  'capabilities',
#  'text data',
#  'Software Type',
#  'arXiv',
#  'ST-VQA',
#  'carbon intensity',
#  'model',
#  'GPUs',
#  'associated text description',
#  'language generation',
#  'aspect ratio',
#  'image-text paired data',
#  'license',
#  'few-shot',
#  'performance metrics',
#  'caption prefix',
#  'trademarks',
#  'auto-regressively',
#  'characteristics',
#  'resizing',
#  'performance',
#  'dataset',
#  'Reference 3',
#  'hyperparameters',
#  'generative nature',
#  'Code snippets',
#  'microsoft/git-base-textvqa',
#  'VQA benchmarks',
#  'Azure Machine Learning',
#  'potential vulnerabilities',
#  'VizWiz-VQA',
#  'Generative Image-to-Text (GIT)',
#  'training data',
#  'dataset size',
#  'occluded',
#  'object detectors',
#  'cosine decay',
#  'training times',
#  'fine-tuning dataset',
#  'sociotechnical impacts',
#  'Performance',
#  'explainability',
#  'visual question answering (VQA)',
#  'A100',
#  'VQAv2',
#  'PyTorch',
#  'iterations',
#  'energy consumption',
#  'legal',
#  'interpretability',
#  'project',
#  'state-of-the-art performance',
#  'visual question answering',
#  'compute resources',
#  'video QA',
#  'fluent sentences',
#  'language modeling loss',
#  'discriminative approach',
#  'GIT models',
#  'preprocessing',
#  'contrastive pre-trained model',
#  'robustness',
#  'projected',
#  'Ref',
#  'poison the output',
#  'analysis',
#  'COCO',
#  'pre-trained model',
#  'fine-tuning',
#  'reference',
#  'large-scale data',
#  'data',
#  'nvidia-docker',
#  'generate',
#  'unreliable',
#  'checkpoint sizes',
#  'evaluating',
#  'visual content',
#  'hardware',
#  'model card',
#  'throughput',
#  'Finetuned',
#  'model explainability',
#  'text decoder',
#  "'inference'",
#  'Transformers',
#  'training time',
#  'layernorm layer',
#  'Generative Image-to-text Transformer',
#  'GPU',
#  'pre-trained',
#  'learning rate',
#  'candidate answers',
#  'model size',
#  'exploit',
#  'demographic groups',
#  'optical character recognition (OCR)',
#  'fine-tuned',
#  'normalized performance difference (NPD)',
#  'ViT',
#  'question answering',
#  'METEOR',
#  'contrastive',
#  'downstream tasks',
#  'Microsoft/git-base-textvqa',
#  'quantitative performance metrics',
#  'large-scale',
#  'recognizing',
#  'visual knowledge',
#  'concatenated',
#  'Training Hyperparameters',
#  'evaluated',
#  'datasets',
#  'metrics',
#  'EOS',
#  'skin tone biases',
#  'sociological',
#  'subgroups',
#  'language modeling objective',
#  'microsoft/git-base-textvqa model',
#  'data domains',
#  'image captioning',
#  'noisy data',
#  'pipeline',
#  'trained',
#  'larger systems',
#  'failure modes',
#  'interdisciplinary',
#  'Robustness',
#  'manipulation',
#  'gender',
#  'BLEU',
#  'encoder',
#  'visual concepts',
#  'model components',
#  'VirTex',
#  'natural language',
#  'handwritten text',
#  'dimensions',
#  'vision-language',
#  'base model',
#  'Bias',
#  'large-scale image-text pairs',
#  'text patterns',
#  'carbon emitted',
#  'Open Source',
#  'extracting features',
#  'feature map',
#  'Microsoft',
#  'ground truth',
#  'image encoder',
#  'CIDEr',
#  'TextVQA dataset',
#  'JPEG format',
#  'scaling up',
#  'initialization',
#  "'prefix'",
#  'embedded',
#  'transformer module',
#  'opencode@microsoft',
#  '8B data',
#  'classification approach',
#  'flattened',
#  'performance trends',
#  'training images',
#  "'test_git_inference_single_image'",
#  'concatenating',
#  'input image',
#  'token',
#  'VizWiz-QA',
#  'potential misunderstandings',
#  'explainable AI',
#  'classification-based approaches',
#  'ethical',
#  'carbon footprint',
#  'logos',
#  'Training Data',
#  'decoder',
#  'malicious actors',
#  'Goyal et al',
#  'scene text',
#  'image-text pairs',
#  'TextVQA evaluation',
#  'object recognition',
#  'error tradeoffs',
#  'benchmarks',
#  'contrastive pretraining',
#  'visual context',
#  'vocabulary knowledge',
#  'BOS',
#  'technical limitations',
#  'discriminative',
#  'tradeoffs',
#  'DeepSpeed',
#  'OSCAR',
#  'TextCaps',
#  'terabytes',
#  'tokenized',
#  'Reference 5',
#  'classifying images',
#  'privacy',
#  'discriminative models',
#  'leveraging',
#  'EOS token',
#  'textual context',
#  'category likelihood',
#  'preprocessed',
#  'evaluation metrics',
#  ' fine-tuning',
#  'pre-training data',
#  'discriminative approaches',
#  'SPICE',
#  'toxic language',
#  'fairness',
#  'skin type',
#  'quantitative results',
#  'accuracy',
#  'inferring',
#  'generative',
#  'git-base-textvqa',
#  'text embeddings',
#  'out-of-domain data',
#  'electricity',
#  'generative approach',
#  'sizes',
#  'contrastive pretraining model',
#  'ecosystems',
#  'LM task',
#  'optimizer',
#  'Azure Blob Storage',
#  'ipc',
#  'py38pt19u20cu11',
#  'nonsensical',
#  'vision-language tasks',
#  'generating captions',
#  'proactively',
#  'architecture',
#  'misleading',
#  'zero-shot',
#  'performance difference',
#  'VQA',
#  'image features',
#  'carbon emission data',
#  'model scaling',
#  ' VQA datasets',
#  'transformer',
#  'pre-training data sources',
#  'captions',
#  'sampled frames',
#  'pre-defined answer candidates',
#  'quality',
#  'video representation',
#  'batch size',
#  'memory',
#  'benchmark',
#  'auto-regressive',
#  'image types',
#  'disaggregated evaluation',
#  'discriminative methods',
#  'surveillance',
#  'A100 GPUs',
#  'pre-defined candidate answers',
#  'language modeling',
#  'Visual Question Answering (VQA)',
#  'evaluation datasets',
#  'performance disparities',
#  'transformer architecture',
#  'image classification']
