# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import pandas as pd
json_lst = json.load(open("json/papers.json", 'r'))
df = pd.DataFrame().from_dict(json_lst)
df
# Out:
#        venue  year             place                  date sub  \
# 0    NeurIPS  2023  New Orleans, USA  December 10-16, 2023  ML
# 1    NeurIPS  2023  New Orleans, USA  December 10-16, 2023  ML
# 2    NeurIPS  2023  New Orleans, USA  December 10-16, 2023  ML
# 3    NeurIPS  2023  New Orleans, USA  December 10-16, 2023  ML
# 4    NeurIPS  2023  New Orleans, USA  December 10-16, 2023  ML
# ..       ...   ...               ...                   ...  ..
# 569      3DV  2013      Seattle, USA      June 29-30, 2013  CV
# 570     ECCV  2012    Firenze, Italy    October 7-13, 2012  CV
# 571     ECCV  2012    Firenze, Italy    October 7-13, 2012  CV
# 572     ICCV  2011  Barcelona, Spain   November 6-13, 2011  CV
# 573     ICCV  2011  Barcelona, Spain   November 6-13, 2011  CV
#
#                                        award  \
# 0               Outstanding Main Track Paper
# 1               Outstanding Main Track Paper
# 2     Outstanding Main Track Runner-Up Paper
# ...

# %%
df.loc[df['year'] == 2023, 'venue'].value_counts()
# Out:
# venue
# ICRA        15
# AAAI        14
# IROS        11
# SIGGRAPH     9
# NeurIPS      7
# ICML         7
# ACL          6
# CVPR         5
# ICCV         4
# RSS          4
# ICLR         4
# CoRL         2
# CASE         1
# Name: count, dtype: int64

# %%
df.loc[df['year'] == 2022, 'venue'].value_counts()
# Out:
# venue
# NeurIPS      16
# ICRA         13
# IROS         12
# ACL          12
# ICML         11
# AAAI         10
# ICLR          7
# SIGGRAPH      5
# 3DV           4
# RSS           4
# CVPR          4
# CoRL          3
# Humanoids     2
# CASE          2
# Name: count, dtype: int64

# %%
df.loc[df['year'] == 2021, 'venue'].value_counts()
# Out:
# venue
# ICRA       12
# AAAI       11
# IROS       10
# NeurIPS     9
# ACL         8
# ICLR        8
# EMNLP       7
# ICML        6
# RSS         5
# 3DV         4
# CASE        4
# CVPR        4
# CoRL        2
# ICCV        2
# Name: count, dtype: int64
