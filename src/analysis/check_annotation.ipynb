# %%
import pandas as pd
df = pd.read_csv("Batch_5251714_batch_results.csv")
df.columns
# Out:
# Index(['HITId', 'HITTypeId', 'Title', 'Description', 'Keywords', 'Reward',
#        'CreationTime', 'MaxAssignments', 'RequesterAnnotation',
#        'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds',
#        'Expiration', 'NumberOfSimilarHITs', 'LifetimeInSeconds',
#        'AssignmentId', 'WorkerId', 'AssignmentStatus', 'AcceptTime',
#        'SubmitTime', 'AutoApprovalTime', 'ApprovalTime', 'RejectionTime',
#        'RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate',
#        'Last30DaysApprovalRate', 'Last7DaysApprovalRate', 'Input.English',
#        'Input.context', 'Input.Arabic', 'Input.Chinese', 'Input.French',
#        'Input.Japanese', 'Input.Russian', 'Answer.corrected_translation',
#        'Answer.high_quality.1', 'Answer.is_familiarity.1',
#        'Answer.low_quality.-1', 'Answer.maybe.0', 'Answer.not_familiarity.0',
#        'Approve', 'Reject'],
#       dtype='object')

# %%
df['Answer.corrected_translation'].value_counts()
# Out:
# Answer.corrected_translation
# NO                                                                                                                                                                                                         2
# Calculate budget                                                                                                                                                                                           1
# 伊弗森括弧                                                                                                                                                                                                      1
# The term "Dice loss" in the context of scientific and machine learning terminology refers to a loss function used to measure the performance of segmentation algorithms, based on the Dice coefficient.    1
# ...

# %%
df['WorkerId'].value_counts()
# Out:
# WorkerId
# AO70MAT1C1VB2     69
# A61OCTW3FD9B      35
# A3O5KMP1WDU2YO    26
# AOZ979BZXLRXI     25
# ALVU74VCMC7TB     24
#                   ..
# AR5QAOVQR0OWN      1
# A2X5EMG9WQP7T5     1
# A1AWR7C38PW42P     1
# A2WZJMNP7WBLNM     1
# A321654GUQQ5M0     1
# Name: count, Length: 256, dtype: int64
