# %% [markdown]
# # whole set

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
lang = "Chinese"


df = pd.read_csv(f"annotation_whole_{lang.lower()}.csv")

cols = []
for i in range(1, 6):
    cols.append(f"Input.English{i}")
    cols.append(f"Input.{lang}{i}")
    cols.append(f"Answer.translation{i}")

df = df[['Title', 'Description', 'Keywords', 'WorkerId'] + cols]
df.columns
# Out:
# Index(['Title', 'Description', 'Keywords', 'WorkerId', 'Input.English1',
#        'Input.Chinese1', 'Answer.translation1', 'Input.English2',
#        'Input.Chinese2', 'Answer.translation2', 'Input.English3',
#        'Input.Chinese3', 'Answer.translation3', 'Input.English4',
#        'Input.Chinese4', 'Answer.translation4', 'Input.English5',
#        'Input.Chinese5', 'Answer.translation5'],
#       dtype='object')

# %%
df.head(50)
# Out:
#                                                 Title  \
# 0   Rate the quality of a translation Test (Chines...
# 1   Rate the quality of a translation Test (Chines...
# 2   Rate the quality of a translation Test (Chines...
# 3   Rate the quality of a translation Test (Chines...
# 4   Rate the quality of a translation Test (Chines...
# 5   Rate the quality of a translation Test (Chines...
# 6   Rate the quality of a translation Test (Chines...
# 7   Rate the quality of a translation Test (Chines...
# 8   Rate the quality of a translation Test (Chines...
# 9   Rate the quality of a translation Test (Chines...
# 10  Rate the quality of a translation Test (Chines...
# 11  Rate the quality of a translation Test (Chines...
# 12  Rate the quality of a translation Test (Chines...
# 13  Rate the quality of a translation Test (Chines...
# 14  Rate the quality of a translation Test (Chines...
# 15  Rate the quality of a translation Test (Chines...
# ...

# %% [markdown]
# # test set

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
lang = "Chinese"


df = pd.read_csv(f"testset_{lang.lower()}.csv")

cols = []
for i in range(1, 6):
    cols.append(f"Input.English_{i}")
    cols.append(f"Input.{lang}_{i}")
    cols.append(f"Answer.translation{i}")

df = df[['Title', 'Description', 'Keywords', 'WorkerId'] + cols]
df.columns
# Out:
# Index(['Title', 'Description', 'Keywords', 'WorkerId', 'Input.English_1',
#        'Input.Chinese_1', 'Answer.translation1', 'Input.English_2',
#        'Input.Chinese_2', 'Answer.translation2', 'Input.English_3',
#        'Input.Chinese_3', 'Answer.translation3', 'Input.English_4',
#        'Input.Chinese_4', 'Answer.translation4', 'Input.English_5',
#        'Input.Chinese_5', 'Answer.translation5'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', None)
df['WorkerId'].value_counts().shape
# Out:
# (90,)

# %%
df['WorkerId'].value_counts()
# Out:
# WorkerId
# A2UX5ABV1UT5U1    5
# A155OW7UP21THF    5
# ABZDE9DEZ52P9     5
# A2AWPIO9IMZO9P    5
# A16LZF91UIO84J    4
# A75XMBFY3UB9C     4
# A2CQSBUU0FQ0PM    4
# ANSNFANEJY1SZ     4
# AZVPAN79C4CY8     4
# A1OLMQU6NU65OM    4
# A2EWL3H4XVVGC1    3
# A3MEWZK69LTDJZ    3
# AXPC0WQ9DAK4I     3
# A385PM8TKY4SBN    3
# A3LU3D1LHPLW6Z    3
# A3EBN8D8YBZ205    3
# AHSXZV2TRQKCU     3
# A33S3NQJEHPOMN    3
# A5SGZNLQXKSB5     3
# A1J8KINFE2DWTR    3
# A5LL8EKITZLQ0     2
# A1YA58RRBN7NI4    2
# A1E34A92PSX82M    2
# A14L5O2IAVTSHD    2
# A9Q02UNHS6TR1     2
# A3JGCW0MKTFPYE    2
# A38DSDPZGUO77O    2
# A3G58G62R7YBAE    2
# A24I2NW1ZVY76S    2
# A310X45W0O0G8F    2
# A32V9WY8YRCAP8    2
# A3KNIP0TZFD4WT    2
# AB2ASFW9CSRX4     2
# A3A6RGC6U41CM5    2
# A3V6NQ85ZZOE0G    1
# A1NKR0W7QUA0CW    1
# A1WU6EAI7ZUTD8    1
# A3BKGBPR9TDO5     1
# A2ZGM0NVVCXMUN    1
# A10S4773ZBOEUU    1
# A1V41YMR4AKA4G    1
# A39NCWTB8S9SVH    1
# A1FSDLJXNLOK3D    1
# AHFIYVWSXHAVK     1
# ...

# %%
df['Input.English_1'].value_counts()
# Out:
# Input.English_1
# constituency parser      30
# text mining              30
# word alignment           30
# convolutional network    30
# attention model          30
# Name: count, dtype: int64

# %%
# chinese
qualified = []
unqualified = ['A3V6NQ85ZZOE0G', 'A36L0Y4GIPC4RT', 'A27I49E3ZGOXPD', 'A1NZZBNAVXCSTS',
 'A1S9SJ5CZTZH1M',
 'A1HU37WA7MHN57',
 'A7F86G1M4A22D',
 'A1PMUCO3BK6C26',
 'A2NMAOYBBJTO0R',
 'A2OHI6FWDK10B2',
 'A1L80XZNXJK57Q',
 'AXTFETMDXEH8E',
 'A1GWX6EL2FV71N',
 'A1WQHQM1TLNU0P',
 'A205UJLRQXJ3LQ',
 'A2I4Y9OC10S8Q4',
 'A3GRZ06RPLS7YO',
 'A3NNEMD2T3YXJO',
 'A2EI5SEWZ699W8',
 'A2C6F3MV97A2YF',
 'AEIDL4NYQG5N0', 'A89MOSYM3Z7NU', 'AEQX4D8XEB8AC', 'AH2ZAM7R9RZYJ', 'A3TUTQYBMO8EVE', 'A2B95TZ8CXMCZ2']

# %%
# arabic
qualified = []
unqualified = ['A16LZF91UIO84J', 'AHFIYVWSXHAVK', 'AB2ASFW9CSRX4', 'A34WFYXGEJ3EBC', 'AR5N626U38LPA',
 'A75XMBFY3UB9C',
 'A1J8KINFE2DWTR',
 'A310X45W0O0G8F',
 'A2UX5ABV1UT5U1',
 'A385PM8TKY4SBN',
 'ANSNFANEJY1SZ',
 'A3KNIP0TZFD4WT',
 'A32V9WY8YRCAP8',
 'A1OWM3QO7QAKBN',
 'A1OLMQU6NU65OM',
 'A14F5XX4Y4KG9P',
 'A2ZM8G6EGJORH3',
 'A2AWPIO9IMZO9P',
 'A1HU37WA7MHN57',
 'A5SGZNLQXKSB5',
 'ABZDE9DEZ52P9',
 'A9Q02UNHS6TR1',
 'AATNSR9QAYC5Q',
 'A3JCU9GCZ8FP97',
 'AHSXZV2TRQKCU',
 'A2QI7OJGJ94BX5',
 'A3JGCW0MKTFPYE',
 'A2I68BIV4JQT2',
 'ARHMCHIBGJ4FS',
 'A2CQSBUU0FQ0PM','AOGUVIIJIXYO3']

# %%
# japanese
unqualified = ['A1SB9YPRBEOQZB',
 'A3V6NQ85ZZOE0G',
 'A3UJE47H1K50LC',
 'AAC5O38A5M1S2',
 'AGTKN7I63HWHK',
 'A1K8ASQMSHKL4F',
 'A3DGD7QAB0WPJX',
 'A249YEMF3IOF8F',
 'A4D99Y82KOLC8',
 'ARHMCHIBGJ4FS',
 'A39FDFI098JTP5',
 'AXXQB17L7J3YH',
 'AGWVZMETSUCX3',
 'A26AH6DPNIH2FQ',
 'A11EI3B3JERT54',
 'A3OUUI8MXMBUTA',
 'A2NMAOYBBJTO0R',
 'A2R8TEJS54TWTU',
 'AXS36Z8214JTS',
 'AOGUVIIJIXYO3',
 'AHFIYVWSXHAVK',
 'A33J90UPYHY7WJ',
 'A7F8W5J23JOTW',
 'AZBP3WE6X2VQV',
 'A1R8VFS8YKJS4Y',
 'AU89IGLQ6AD15', 'A146KBI8D4W4WG', 'A1RAJW5O9HPPE2', 'A14F5XX4Y4KG9P', 'A2I68BIV4JQT2', 'A334XBMTC9R27G', 'A14ZPKPAPASF9U', 'A4PMJXTA7ARKK', 'A34I1UGKSNQR19', 'A1B2BTCGBB6IAM', 'A1IVT8140ZLTPC', 'A2AKGCCDHISUL2', 'A33C0IP40ZZPKS', 'A1X1DXK737Y6BX']

# %%
# russian
qualified = []
unqualified = ['A124QC05SSRJC3', 'A14ZPKPAPASF9U', 'AAC5O38A5M1S2', 'A3V6NQ85ZZOE0G', 'AD0XVQHIIJ3RP', 'A2OHI6FWDK10B2', 'AH2ZAM7R9RZYJ', 'A3D07A2MNDBKXK', 'AV06F0ZLGC1IN', 'A1K8ASQMSHKL4F', 'A30HJVRR2UWFKT', 'A2P2UPJBOGP2X3', 'AR5QAOVQR0OWN', 'A3EJ5A0GPHKO9J', 'A38SEBVG1J8TH7', 'A3KPN42GS526BV', 'AJIBKYHREAFYX', 'A23A5MAUY0PF30', 'A3EAM8CRMJ51KX', 'A5LIMBZCZR3FD', 'AW9EDTAGKNC57', 'A1BMCLI45I47Z3', 'A3ORTMILSRG4HL', 'AGTKN7I63HWHK', 'A2FWE58QKZAUVL', 'A2B9IE51SDRIDV']

# %%
df.loc[(df['Input.English_1'] == "attention model") & (~df['WorkerId'].isin(unqualified))]
# Out:
#                                                  Title  \
# 120  Rate the quality of a translation Test (Chines...
# 121  Rate the quality of a translation Test (Chines...
# 122  Rate the quality of a translation Test (Chines...
# 125  Rate the quality of a translation Test (Chines...
# 127  Rate the quality of a translation Test (Chines...
# 128  Rate the quality of a translation Test (Chines...
# 129  Rate the quality of a translation Test (Chines...
# 130  Rate the quality of a translation Test (Chines...
# 131  Rate the quality of a translation Test (Chines...
# 132  Rate the quality of a translation Test (Chines...
# 133  Rate the quality of a translation Test (Chines...
# 134  Rate the quality of a translation Test (Chines...
# 136  Rate the quality of a translation Test (Chines...
# 137  Rate the quality of a translation Test (Chines...
# 138  Rate the quality of a translation Test (Chines...
# 139  Rate the quality of a translation Test (Chines...
# ...

# %%
list(set(df['WorkerId'].unique().tolist()).difference(set(unqualified)))
# Out:
# ['A3DIAIOB1DURSN',
#  'A2KVEENUGDUVCA',
#  'AATGWVVPQJSIT',
#  'A1RAJW5O9HPPE2',
#  'A3BAG557BXSRF6',
#  'A1F8RTA04QKNFY',
#  'A2BK919J29TOEE',
#  'A2ZN3Q6015GOUA',
#  'A27IWP9QQQBX44',
#  'A2P2UPJBOGP2X3',
#  'A18CB87XJS64Z0',
#  'A15VQD1AZ0M6XO',
#  'A1GMWF04URJMID',
#  'A39FMG8IFNI7ZH',
#  'A1K8ASQMSHKL4F',
#  'A2RFY9YXUWY2E1',
#  'A2A5EJSJ1F1ZBP',
#  'A3ND1PA3UG9DXF',
#  'A1WU6EAI7ZUTD8',
#  'A336SDY652S9GU',
#  'A24Z95OIWVVVG5',
#  'A4TT6QM1DNVDW',
#  'A18BYZ5AOGG4PZ',
#  'A1XFP99524J1AH',
#  'A3AO3IL9E9N3KG',
#  'A2BHV2GVLH0E7F',
#  'A18YWTRM269A46',
#  'A2QI7OJGJ94BX5',
#  'A1OSAIXJPUXJFO',
#  'A3EBN8D8YBZ205',
#  'A39NCWTB8S9SVH',
#  'A2IU5W5ZRWT2IJ',
#  'A3KNIP0TZFD4WT',
#  'AR9SXKQ8Q7HLG',
#  'A3BM1VCX0Q3UYD',
#  'A25HETTI76GHCL',
#  'A291EAOGL08IFT',
#  'A29317JWUEQHQS',
#  'AWK89QECL03SP',
#  'A11TLWECSEYVCV',
#  'A39XTLND9LZCIE',
#  'A36CA3E5LT6I1P',
#  'A1NCJ9ZW5VRLQI',
#  'AXPTF739HYEZX',
#  'A2VNIOI5GX51C6',
#  'AQHKPPYJJBSI9',
#  'A1XTTWEHGSK356',
# ...

# %%
df.loc[(df['Input.English_1'] == 'attention model') & (~df['WorkerId'].isin(unqualified))]
# Out:
#                                                  Title  \
# 120  Rate the quality of a translation Test (Japane...
# 121  Rate the quality of a translation Test (Japane...
# 123  Rate the quality of a translation Test (Japane...
# 124  Rate the quality of a translation Test (Japane...
# 126  Rate the quality of a translation Test (Japane...
# 127  Rate the quality of a translation Test (Japane...
# 128  Rate the quality of a translation Test (Japane...
# 129  Rate the quality of a translation Test (Japane...
# 130  Rate the quality of a translation Test (Japane...
# 131  Rate the quality of a translation Test (Japane...
# 132  Rate the quality of a translation Test (Japane...
# 133  Rate the quality of a translation Test (Japane...
# 134  Rate the quality of a translation Test (Japane...
# 135  Rate the quality of a translation Test (Japane...
# 136  Rate the quality of a translation Test (Japane...
# 137  Rate the quality of a translation Test (Japane...
# ...

# %%
worker_id = "A3V6NQ85ZZOE0G"
df.loc[df['WorkerId'] == worker_id]
# Out:
#                                                Title  \
# 5  Rate the quality of a translation Test (Japane...
#
#                                          Description  \
# 5  In this task, you will be evaluating the quali...
#
#                                          Keywords        WorkerId  \
# 5  Translation, Terminology, Multilingual, Rating  A3V6NQ85ZZOE0G
#
#        Input.English_1 Input.Japanese_1  Answer.translation1  \
# 5  constituency parser          構成素パーサー  شبكة عصبية التفافية
#
#         Input.English_2 Input.Japanese_2  Answer.translation2  \
# 5  constituency parsing            構成素解析  شبكة عصبية التفافية
#
#      Input.English_3         Input.Japanese_3  Answer.translation3  \
# 5  constituency tree  構成要素木 (kousei youso ki)  شبكة عصبية التفافية
#
#        Input.English_4 Input.Japanese_4  Answer.translation4  \
# 5  constituent parsing            構成素解析  شبكة عصبية التفافية
#
#          Input.English_5 Input.Japanese_5  Answer.translation5
# ...
