# %%
from huggingface_hub import HfApi, create_repo, upload_folder

# Replace with your info
repo_name = "multilingual-terminology"
dataset_path = "/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_final"
token = "<hf_token>"

username = "Jerry999"  # or use `api.whoami(token)["name"]`

api = HfApi()

full_repo_id = f"{username}/{repo_name}"
api.create_repo(repo_id=full_repo_id, repo_type="dataset", token=token, exist_ok=True)

# 📤 Upload your dataset folder
upload_folder(
    repo_id=full_repo_id,
    repo_type="dataset",
    folder_path=dataset_path,
    token=token,
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/datasets/Jerry999/multilingual-terminology/commit/9bae59ac19337f147aa530e7ac05b6b03403d2a5', commit_message='Upload folder using huggingface_hub', commit_description='', oid='9bae59ac19337f147aa530e7ac05b6b03403d2a5', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Jerry999/multilingual-terminology', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Jerry999/multilingual-terminology'), pr_revision=None, pr_num=None)
