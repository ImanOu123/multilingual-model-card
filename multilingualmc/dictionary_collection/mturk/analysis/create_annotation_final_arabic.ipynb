# %% [markdown]
# Two sources:
# 1. `multilingualmc/dictionary_collection/mturk/analysis`
# 2. `multilingualmc/data_term_gold/processed`

# %%
import pandas as pd
import json
data_gold = pd.read_json("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/data_term_gold/processed/arabic.json").rename(columns={"term_reformatted": "word", "term_arabic": "validated_translation"}, inplace=False).drop_duplicates(subset='word', inplace=False)
data_gold['word_lower'] = data_gold['word'].str.lower()
data_6060 = pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_results_6060/Arabic_validated.csv").rename(columns={"validated_translation": "validated_translation_old", "gold": "validated_translation"}, inplace=False).drop_duplicates(subset='word', inplace=False)
data_mturk = pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_results_crawled/Arabic_validated.csv").drop_duplicates(subset='word', inplace=False)

# %%
concat_df = pd.concat([data_6060[['word', 'validated_translation']], data_mturk[['word', 'validated_translation']]], axis=0, ignore_index=True)
concat_df['word_lower'] = concat_df['word'].str.lower()
concat_df
# Out:
#                              word       validated_translation  \
# 0                              AI                          AI
# 1                             API                         API
# 2                             AQA                         AQA
# 3                           ARENA                       ARENA
# 4                    Additionally           وبالإضافة إلى ذلك
# ...                           ...                         ...
# 4985          zero-shot prompting          التحفيز بدون أمثلة
# 4986          zero-shot reasoning  الاستدلال بدون أمثلة سابقة
# 4987            zero-shot setting            إعداد بدون أمثلة
# 4988           zero-shot transfer                النقل الصفري
# 4989  zero-shot transfer learning  التعلم بالتحويل بدون تدريب
#
#                        word_lower
# 0                              ai
# 1                             api
# 2                             aqa
# 3                           arena
# 4                    additionally
# ...                           ...
# 4985          zero-shot prompting
# 4986          zero-shot reasoning
# 4987            zero-shot setting
# 4988           zero-shot transfer
# 4989  zero-shot transfer learning
#
# [4990 rows x 3 columns]

# %%
lang='Arabic'
concat_df_ref = pd.read_csv(f"/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_results_crawled/{lang}_validated_>0.5.csv")[['word', 'validated_translation']]

concat_df_ref = concat_df_ref.dropna(subset=['validated_translation'])

translation_dict = concat_df_ref.set_index("word")["validated_translation"].to_dict()

# Replace "validated_translation" in df where the "word" exists in df_ref
concat_df["validated_translation"] = concat_df.apply(
    lambda row: translation_dict[row["word"]] if row["word"] in translation_dict else row["validated_translation"],
    axis=1
)

# %%
df_itst = pd.merge(data_gold[['word', 'word_lower', 'validated_translation']], concat_df[['word', 'word_lower', 'validated_translation']], on='word_lower')
df_itst[df_itst['validated_translation_x'] == df_itst['validated_translation_y']].shape[0] / df_itst.shape[0], df_itst[df_itst['validated_translation_x'] == df_itst['validated_translation_y']].shape[0], df_itst.shape[0]
# Out:
# (0.21359223300970873, 22, 103)

# %%
# def levenshtein_distance(str1, str2):
#     # Initialize matrix of distances
#     dp = [[0] * (len(str2) + 1) for _ in range(len(str1) + 1)]

#     # Base cases
#     for i in range(len(str1) + 1):
#         dp[i][0] = i
#     for j in range(len(str2) + 1):
#         dp[0][j] = j

#     # Fill the matrix
#     for i in range(1, len(str1) + 1):
#         for j in range(1, len(str2) + 1):
#             if str1[i - 1] == str2[j - 1]:
#                 dp[i][j] = dp[i - 1][j - 1]  # No operation needed
#             else:
#                 dp[i][j] = min(dp[i - 1][j] + 1,      # Deletion
#                                dp[i][j - 1] + 1,      # Insertion
#                                dp[i - 1][j - 1] + 1)  # Substitution

#     # The distance is in the bottom-right cell
#     return dp[-1][-1]

# df_itst['levenshtein_dist'] = df_itst.apply(lambda x: levenshtein_distance(x['validated_translation_x'], x['validated_translation_y']), axis=1)

# %%
df_itst
# Out:
#                           word_x                   word_lower  \
# 0        artificial intelligence      artificial intelligence
# 1               machine learning             machine learning
# 2                  deep learning                deep learning
# 3      artificial neural network    artificial neural network
# 4    natural language processing  natural language processing
# ..                           ...                          ...
# 98                   Turing test                  turing test
# 99                 self-training                self-training
# 100            domain adaptation            domain adaptation
# 101           federated learning           federated learning
# 102        commonsense reasoning        commonsense reasoning
#
#     validated_translation_x                       word_y  \
# 0              ذكاء اصطناعي      Artificial Intelligence
# 1              تعُّلم الآلة             Machine Learning
# 2               تعُّلم عميق                Deep Learning
# 3       شبكة عصبية اصطناعية    artificial neural network
# 4    معالجة اللغات الطبيعية  Natural Language Processing
# ..                      ...                          ...
# 98            اختبار تورينج                  Turing Test
# 99               تدريب ذاتي                self-training
# 100            تكييف المجال            Domain Adaptation
# 101               تعلم متحد           Federated Learning
# 102           استدلال بديهي        Commonsense Reasoning
#
#     validated_translation_y
# 0          الذكاء الاصطناعي
# 1                تعلم الآلة
# 2             التعلم العميق
# 3       شبكة عصبية اصطناعية
# 4     معالجة اللغة الطبيعية
# ..                      ...
# 98            اختبار تورينج
# 99           التدريب الذاتي
# 100           التكيف المجال
# 101        التعلم الفيدرالي
# 102       الاستدلال البديهي
#
# [103 rows x 5 columns]

# %%
# import matplotlib.pyplot as plt
# import pandas as pd


# # Plot the distribution of the 'values' column
# plt.figure(figsize=(8, 5))
# plt.hist(df_itst['levenshtein_dist'], bins=10, edgecolor='black', alpha=0.7)
# plt.xlabel('levenshtein_dist')
# plt.ylabel('Frequency')
# plt.title('Distribution of Values')
# plt.show()

# %%
merged_df = pd.merge(concat_df[['word', 'word_lower', 'validated_translation']], data_gold[['word', 'word_lower', 'validated_translation']], on="word_lower", how='outer', suffixes=('_df2', '_df1'))
merged_df
# Out:
#                          word_df2                   word_lower  \
# 0        10-fold cross validation     10-fold cross validation
# 1                  1D convolution               1d convolution
# 2                          2 norm                       2 norm
# 3                  2D convolution               2d convolution
# 4                        2D image                     2d image
# ...                           ...                          ...
# 5059           zero-shot transfer           zero-shot transfer
# 5060  zero-shot transfer learning  zero-shot transfer learning
# 5061                         Zipf                         zipf
# 5062            Zipf distribution            zipf distribution
# 5063                   Zipf's law                   zipf's law
#
#        validated_translation_df2 word_df1 validated_translation_df1
# 0      التحقق المتقاطع بعشر طيات      NaN                       NaN
# 1          الالتفاف أحادي البُعد      NaN                       NaN
# 2                       النورم 2      NaN                       NaN
# 3         الالتفاف ثنائي الأبعاد      NaN                       NaN
# 4            صورة ثنائية الأبعاد      NaN                       NaN
# ...                          ...      ...                       ...
# 5059                النقل الصفري      NaN                       NaN
# 5060  التعلم بالتحويل بدون تدريب      NaN                       NaN
# 5061                        زيبف      NaN                       NaN
# 5062                 توزيع زيـبف      NaN                       NaN
# 5063                  قانون زيبف      NaN                       NaN
#
# [5064 rows x 5 columns]

# %%
merged_df['validated_translation'] = merged_df['validated_translation_df1'].combine_first(merged_df['validated_translation_df2'])
merged_df['word'] = merged_df['word_df1'].combine_first(merged_df['word_df2'])
merged_df
# Out:
#                          word_df2                   word_lower  \
# 0        10-fold cross validation     10-fold cross validation
# 1                  1D convolution               1d convolution
# 2                          2 norm                       2 norm
# 3                  2D convolution               2d convolution
# 4                        2D image                     2d image
# ...                           ...                          ...
# 5059           zero-shot transfer           zero-shot transfer
# 5060  zero-shot transfer learning  zero-shot transfer learning
# 5061                         Zipf                         zipf
# 5062            Zipf distribution            zipf distribution
# 5063                   Zipf's law                   zipf's law
#
#        validated_translation_df2 word_df1 validated_translation_df1  \
# 0      التحقق المتقاطع بعشر طيات      NaN                       NaN
# 1          الالتفاف أحادي البُعد      NaN                       NaN
# 2                       النورم 2      NaN                       NaN
# 3         الالتفاف ثنائي الأبعاد      NaN                       NaN
# 4            صورة ثنائية الأبعاد      NaN                       NaN
# ...                          ...      ...                       ...
# 5059                النقل الصفري      NaN                       NaN
# 5060  التعلم بالتحويل بدون تدريب      NaN                       NaN
# 5061                        زيبف      NaN                       NaN
# 5062                 توزيع زيـبف      NaN                       NaN
# 5063                  قانون زيبف      NaN                       NaN
#
#            validated_translation                         word
# 0      التحقق المتقاطع بعشر طيات     10-fold cross validation
# 1          الالتفاف أحادي البُعد               1D convolution
# 2                       النورم 2                       2 norm
# 3         الالتفاف ثنائي الأبعاد               2D convolution
# 4            صورة ثنائية الأبعاد                     2D image
# ...                          ...                          ...
# 5059                النقل الصفري           zero-shot transfer
# 5060  التعلم بالتحويل بدون تدريب  zero-shot transfer learning
# 5061                        زيبف                         Zipf
# 5062                 توزيع زيـبف            Zipf distribution
# 5063                  قانون زيبف                   Zipf's law
#
# [5064 rows x 7 columns]

# %%
ref_df = pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_final/Chinese.csv")
ref_df['word_lower'] = ref_df['word'].str.lower()

# %%
merged_df = merged_df[['word', 'validated_translation']].drop_duplicates(subset='word', inplace=False).sort_values(by='word')
merged_df['word_lower'] = merged_df['word'].str.lower()

merged = merged_df.merge(ref_df[['word', 'word_lower']], on='word_lower', how='left', suffixes=('', '_ref'))

# Update 'word' in merged_df with the 'word' from ref_df where it matches
merged['word'] = merged['word_ref'].combine_first(merged['word'])

# Drop the temporary 'word_ref' column used for merging
merged = merged.drop(columns=['word_ref'])
merged
# Out:
#                              word       validated_translation  \
# 0        10-fold cross validation   التحقق المتقاطع بعشر طيات
# 1                  1D convolution       الالتفاف أحادي البُعد
# 2                          2 norm                    النورم 2
# 3                  2D convolution      الالتفاف ثنائي الأبعاد
# 4                        2D image         صورة ثنائية الأبعاد
# ...                           ...                         ...
# 5066          zero-shot prompting    التوجيه بدون أمثلة سابقة
# 5067          zero-shot reasoning  الاستدلال بدون أمثلة سابقة
# 5068            zero-shot setting          الإعداد بدون أمثلة
# 5069           zero-shot transfer                النقل الصفري
# 5070  zero-shot transfer learning  التعلم بالتحويل بدون تدريب
#
#                        word_lower
# 0        10-fold cross validation
# 1                  1d convolution
# 2                          2 norm
# 3                  2d convolution
# 4                        2d image
# ...                           ...
# 5066          zero-shot prompting
# 5067          zero-shot reasoning
# 5068            zero-shot setting
# 5069           zero-shot transfer
# 5070  zero-shot transfer learning
#
# [5071 rows x 3 columns]

# %%
merged = merged.drop_duplicates(subset='word_lower', inplace=False)[['word', 'validated_translation']].sort_values(by='word')
merged.to_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_final/Arabic.csv")
