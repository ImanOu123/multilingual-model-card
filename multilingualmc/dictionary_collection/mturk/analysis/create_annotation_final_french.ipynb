# %% [markdown]
# Two sources:
# 1. `multilingualmc/dictionary_collection/mturk/analysis`
# 2. `multilingualmc/data_term_gold/processed`

# %%
import pandas as pd
import json
data_gold = pd.read_json("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/data_term_gold/processed/french.json").rename(columns={"term_reformatted": "word", "term_french_reformatted": "validated_translation"}, inplace=False).drop_duplicates(subset='word', inplace=False)
data_gold['word_lower'] = data_gold['word'].str.lower()
data_6060 = pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_results_6060/French_validated.csv").rename(columns={"validated_translation": "validated_translation_old", "gold": "validated_translation"}, inplace=False).drop_duplicates(subset='word', inplace=False)
data_mturk = pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_results_crawled/French_validated.csv").drop_duplicates(subset='word', inplace=False)

# %%
concat_df = pd.concat([data_6060[['word', 'validated_translation']], data_mturk[['word', 'validated_translation']]], axis=0, ignore_index=True)
concat_df['word_lower'] = concat_df['word'].str.lower()
concat_df
# Out:
#                              word                  validated_translation  \
# 0                              AI              intelligence artificielle
# 1                             API                                    API
# 2                             AQA                                    AQA
# 3                           ARENA                                  ARENA
# 4                    Additionally                                de plus
# ...                           ...                                    ...
# 4985          zero-shot prompting        amorçage sans exemple préalable
# 4986          zero-shot reasoning    raisonnement sans exemple préalable
# 4987            zero-shot setting                 contexte sans exemples
# 4988           zero-shot transfer                    transfert zéro-shot
# 4989  zero-shot transfer learning  apprentissage par transfert zéro-shot
#
#                        word_lower
# 0                              ai
# 1                             api
# 2                             aqa
# 3                           arena
# 4                    additionally
# ...                           ...
# 4985          zero-shot prompting
# 4986          zero-shot reasoning
# 4987            zero-shot setting
# 4988           zero-shot transfer
# 4989  zero-shot transfer learning
#
# [4990 rows x 3 columns]

# %%
lang='French'
concat_df_ref = pd.read_csv(f"/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_results_crawled/{lang}_validated_>0.5.csv")[['word', 'validated_translation']]

concat_df_ref = concat_df_ref.dropna(subset=['validated_translation'])

translation_dict = concat_df_ref.set_index("word")["validated_translation"].to_dict()

# Replace "validated_translation" in df where the "word" exists in df_ref
concat_df["validated_translation"] = concat_df.apply(
    lambda row: translation_dict[row["word"]] if row["word"] in translation_dict else row["validated_translation"],
    axis=1
)

# %%
df_itst = pd.merge(data_gold[['word', 'word_lower', 'validated_translation']], concat_df[['word', 'word_lower', 'validated_translation']], on='word_lower')
df_itst[df_itst['validated_translation_x'] == df_itst['validated_translation_y']].shape[0] / df_itst.shape[0], df_itst[df_itst['validated_translation_x'] == df_itst['validated_translation_y']].shape[0], df_itst.shape[0]
# Out:
# (0.42780748663101603, 240, 561)

# %%
# def levenshtein_distance(str1, str2):
#     # Initialize matrix of distances
#     dp = [[0] * (len(str2) + 1) for _ in range(len(str1) + 1)]

#     # Base cases
#     for i in range(len(str1) + 1):
#         dp[i][0] = i
#     for j in range(len(str2) + 1):
#         dp[0][j] = j

#     # Fill the matrix
#     for i in range(1, len(str1) + 1):
#         for j in range(1, len(str2) + 1):
#             if str1[i - 1] == str2[j - 1]:
#                 dp[i][j] = dp[i - 1][j - 1]  # No operation needed
#             else:
#                 dp[i][j] = min(dp[i - 1][j] + 1,      # Deletion
#                                dp[i][j - 1] + 1,      # Insertion
#                                dp[i - 1][j - 1] + 1)  # Substitution

#     # The distance is in the bottom-right cell
#     return dp[-1][-1]

# df_itst['levenshtein_dist'] = df_itst.apply(lambda x: levenshtein_distance(x['validated_translation_x'], x['validated_translation_y']), axis=1)

# %%
# import matplotlib.pyplot as plt
# import pandas as pd


# # Plot the distribution of the 'values' column
# plt.figure(figsize=(8, 5))
# plt.hist(df_itst['levenshtein_dist'], bins=20, edgecolor='black', alpha=0.7)
# plt.xlabel('levenshtein_dist')
# plt.ylabel('Frequency')
# plt.title('Distribution of Values')
# plt.show()

# %%
merged_df = pd.merge(concat_df[['word', 'word_lower', 'validated_translation']], data_gold[['word', 'word_lower', 'validated_translation']], on="word_lower", how='outer', suffixes=('_df2', '_df1'))
merged_df
# Out:
#                       word_df2                word_lower  \
# 0     10-fold cross validation  10-fold cross validation
# 1               1D convolution            1d convolution
# 2                       2 norm                    2 norm
# 3                          NaN   2 x 2 contingency table
# 4               2D convolution            2d convolution
# ...                        ...                       ...
# 6742                      Zipf                      zipf
# 6743         Zipf distribution         zipf distribution
# 6744                Zipf's law                zipf's law
# 6745                       NaN                         ŷ
# 6746                       NaN                 αβ search
#
#          validated_translation_df2                 word_df1  \
# 0     validation croisée à 10 plis                      NaN
# 1                   convolution 1D                      NaN
# 2                          Norme 2                      NaN
# 3                              NaN  2 x 2 contingency table
# 4                   convolution 2D                      NaN
# ...                            ...                      ...
# 6742                          Zipf                      NaN
# 6743          Distribution de Zipf                      NaN
# 6744                   Loi de Zipf               Zipf's law
# 6745                           NaN                        ŷ
# 6746                           NaN                αβ search
#
#        validated_translation_df1
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3     table de contingence 2 x 2
# 4                            NaN
# ...                          ...
# 6742                         NaN
# 6743                         NaN
# 6744                 loi de Zipf
# 6745                       y hat
# 6746        recherche alpha-bêta
#
# [6747 rows x 5 columns]

# %%
merged_df['validated_translation'] = merged_df['validated_translation_df1'].combine_first(merged_df['validated_translation_df2'])
merged_df['word'] = merged_df['word_df1'].combine_first(merged_df['word_df2'])
merged_df
# Out:
#                       word_df2                word_lower  \
# 0     10-fold cross validation  10-fold cross validation
# 1               1D convolution            1d convolution
# 2                       2 norm                    2 norm
# 3                          NaN   2 x 2 contingency table
# 4               2D convolution            2d convolution
# ...                        ...                       ...
# 6742                      Zipf                      zipf
# 6743         Zipf distribution         zipf distribution
# 6744                Zipf's law                zipf's law
# 6745                       NaN                         ŷ
# 6746                       NaN                 αβ search
#
#          validated_translation_df2                 word_df1  \
# 0     validation croisée à 10 plis                      NaN
# 1                   convolution 1D                      NaN
# 2                          Norme 2                      NaN
# 3                              NaN  2 x 2 contingency table
# 4                   convolution 2D                      NaN
# ...                            ...                      ...
# 6742                          Zipf                      NaN
# 6743          Distribution de Zipf                      NaN
# 6744                   Loi de Zipf               Zipf's law
# 6745                           NaN                        ŷ
# 6746                           NaN                αβ search
#
#        validated_translation_df1         validated_translation  \
# 0                            NaN  validation croisée à 10 plis
# 1                            NaN                convolution 1D
# 2                            NaN                       Norme 2
# 3     table de contingence 2 x 2    table de contingence 2 x 2
# 4                            NaN                convolution 2D
# ...                          ...                           ...
# 6742                         NaN                          Zipf
# 6743                         NaN          Distribution de Zipf
# 6744                 loi de Zipf                   loi de Zipf
# 6745                       y hat                         y hat
# 6746        recherche alpha-bêta          recherche alpha-bêta
#
#                           word
# 0     10-fold cross validation
# 1               1D convolution
# 2                       2 norm
# 3      2 x 2 contingency table
# 4               2D convolution
# ...                        ...
# 6742                      Zipf
# 6743         Zipf distribution
# 6744                Zipf's law
# 6745                         ŷ
# 6746                 αβ search
#
# [6747 rows x 7 columns]

# %%
ref_df = pd.concat([pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_final/Chinese.csv"), pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_final/Arabic.csv"), pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_final/Russian.csv"), pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_final/Japanese.csv")], axis=0).drop_duplicates(subset='word', inplace=False)
ref_df['word_lower'] = ref_df['word'].str.lower()

# %%
merged_df = merged_df[['word', 'validated_translation']].drop_duplicates(subset='word', inplace=False).sort_values(by='word')
merged_df['word_lower'] = merged_df['word'].str.lower()

merged = merged_df.merge(ref_df[['word', 'word_lower']], on='word_lower', how='left', suffixes=('', '_ref'))

# Update 'word' in merged_df with the 'word' from ref_df where it matches
merged['word'] = merged['word_ref'].combine_first(merged['word'])

# Drop the temporary 'word_ref' column used for merging
merged = merged.drop(columns=['word_ref'])
merged
# Out:
#                              word                  validated_translation  \
# 0        10-fold cross validation           validation croisée à 10 plis
# 1                  1D convolution                         convolution 1D
# 2                          2 norm                                Norme 2
# 3         2 x 2 contingency table             table de contingence 2 x 2
# 4                  2D convolution                         convolution 2D
# ...                           ...                                    ...
# 6743           zero-shot transfer                    transfert zéro-shot
# 6744  zero-shot transfer learning  apprentissage par transfert zéro-shot
# 6745                    zettabyte                             zettaoctet
# 6746                            ŷ                                  y hat
# 6747                    αβ search                   recherche alpha-bêta
#
#                        word_lower
# 0        10-fold cross validation
# 1                  1d convolution
# 2                          2 norm
# 3         2 x 2 contingency table
# 4                  2d convolution
# ...                           ...
# 6743           zero-shot transfer
# 6744  zero-shot transfer learning
# 6745                    zettabyte
# 6746                            ŷ
# 6747                    αβ search
#
# [6748 rows x 3 columns]

# %%
merged = merged.drop_duplicates(subset='word_lower', inplace=False)[['word', 'validated_translation']].sort_values(by='word')
merged.to_csv("/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_final/French.csv")
