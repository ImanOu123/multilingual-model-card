# %%
import pandas as pd
df = pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/src/dictionary_collection/mturk/mturk_with_6060.csv")
df_wiki = pd.read_csv("/home/jiaruil5/multilingual/multilingual-model-card/src/dictionary_collection/processed_data/wiki_ai.csv")
data_wiki = []
data = []
for item in df['English'].tolist():
    data.append(item.lower())
for item in df_wiki['term'].tolist():
    data_wiki.append(item.lower())

len(data), len(data_wiki)
# Out:
# (5027, 352)

# %%
data = set(data)
data_wiki = set(data_wiki)
len(data), len(data_wiki)
# Out:
# (4971, 351)

# %%
intersection = list(data & data_wiki)
len(intersection)
# Out:
# 94
