# %%
import pandas as pd
langs = ['French', 'Japanese', 'Arabic', 'Chinese', 'Russian']
for lang in langs:
    df = pd.read_csv("annotation_final/French.csv")
df
# Out:
#       Unnamed: 0                         word  \
# 0              0     10-fold cross validation
# 1              1               1D convolution
# 2              2                       2 norm
# 3              3      2 x 2 contingency table
# 4              4               2D convolution
# ...          ...                          ...
# 6723        6743           zero-shot transfer
# 6724        6744  zero-shot transfer learning
# 6725        6745                    zettabyte
# 6726        6746                            ŷ
# 6727        6747                    αβ search
#
#                       validated_translation
# 0              validation croisée à 10 plis
# 1                            convolution 1D
# 2                                   norme 2
# 3                table de contingence 2 x 2
# 4                            convolution 2D
# ...                                     ...
# 6723                    transfert zéro-shot
# 6724  apprentissage par transfert zéro-shot
# ...
