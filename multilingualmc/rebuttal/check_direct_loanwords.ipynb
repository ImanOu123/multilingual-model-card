# %%
import pandas as pd

tgt_langs = [
    "Arabic",
    "Chinese",
    "French", 
    "Japanese",
    "Russian"
]

for tgt_lang in tgt_langs:
    df = pd.read_csv(f"/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_final/{tgt_lang}.csv")
    print(tgt_lang)
    print(df.loc[df['English'].str.lower() == df[tgt_lang].str.lower()].shape[0] / df.shape[0])
# Out:
# Arabic
# 0.012386457473162676
# Chinese
# 0.014005602240896359
# French
# 0.053470200704764825
# Japanese
# 0.014675052410901468
# Russian
# 0.0185794464873234
