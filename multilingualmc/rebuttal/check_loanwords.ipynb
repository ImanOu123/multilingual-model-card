# %%
import json

tgt_langs = [
    "Chinese",
    "Arabic",
    "French",
    "Japanese",
    "Russian",
]

for tgt_lang in tgt_langs:
    print(tgt_lang)
    file = [json.loads(i)['is_translated'] for i in open(f"loanwords{tgt_lang}.jsonl", 'r').readlines()]
    print(sum(file) / len(file))
# Out:
# Chinese
# 0.9502023031434796
# Arabic
# 0.7299752270850537
# French
# 0.719626168224299
# Japanese
# 0.5375262054507337
# Russian
# 0.804528740081285
