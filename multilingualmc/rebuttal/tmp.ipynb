# %%
import pandas as pd
import json
data = [json.loads(i)['English'] for i in open("translations/gpt-4o_Chinese.jsonl", 'r').readlines()]

json.dump(data, open("translations/sample_500.json", 'w'), ensure_ascii=False, indent=2)
