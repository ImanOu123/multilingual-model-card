# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/jiaruil5/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from multilingualmc.translator.get_terms import TermCollector
tgt_langs = [
    "Chinese",
    "Arabic",
    "French",
    "Japanese",
    "Russian",
]

term_collector = TermCollector(
    "/home/jiaruil5/multilingual/multilingual-model-card/multilingualmc/dictionary_collection/mturk/analysis/annotation_final",
    tgt_langs = tgt_langs
)

# %%
term_collector.terms_dict['10-fold cross validation']
# Out:
# {'Chinese': '10折交叉验证',
#  'Arabic': 'التحقق المتقاطع بعشر طيات',
#  'French': 'validation croisée à 10 plis',
#  'Japanese': '10分割交差検証',
#  'Russian': '10-кратная кросс-валидация'}

# %%
term_collector.find_terminology("""1: For all the methods, we used <mark>10-fold cross validation</mark> (i.e., each fold we have 556 training and 62 test samples) to tune free parameters, e.g., the kernel form and parameters for GPOR and LapSVM. Note that all the alternative methods stack X and Z together into a whole data matrix and ignore their heterogeneous nature.<br>2: Features associated one-to-one with a vertical (Clarity, ReDDE, the query likelihood given the vertical's query-log and Soft.ReDDE) were normalized across verticals before scaling. Supervised training/testing was done via <mark>10-fold cross validation</mark>. Parameter τ was tuned for each training fold on the same 500 query validation set used for our single feature baselines.""")
# Out:
# {'10-fold cross validation',
#  'feature',
#  'kernel',
#  'likelihood',
#  'matrix',
#  'normalized',
#  'scaling',
#  'supervised',
#  'test',
#  'training',
#  'validation set'}
