# %%
# %load_ext autoreload
# %autoreload 2

# %%
from multilingualmc.translator.config import NLLBTranslatorConfig
from multilingualmc.translator.translator import NLLBTranslator
trans_args = NLLBTranslatorConfig
translator = NLLBTranslator(trans_args)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/data/user_data/jiaruil5/miniconda3/envs/mmc/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/data/user_data/jiaruil5/miniconda3/envs/mmc/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/data/user_data/jiaruil5/miniconda3/envs/mmc/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
# ...

# %%
translator.translate(
    """Hi, this is Elena and I'm going to be presenting our work, Detecting Unassimilated Borrowings in Spanish: An Annotated Corpus and Approaches to Modeling.\n""",
    src_lang = "English",
    tgt_lang = "Chinese",
)
# Out:
# the `lang_code_to_id` attribute is deprecated. The logic is natively handled in the `tokenizer.adder_tokens_decoder` this attribute will be removed in `transformers` v4.38
# '现在我们将在西班牙语中探测未被吸收的借用:一个注释的语料库和模型的方法.'

# %%
translator.src_lang = translator.args.lang_dict['Chinese']
translator.tokenizer(
    '多步推理',
    add_special_tokens=False
).input_ids
# Out:
# [68500, 251806, 250973, 249418]

# %%
translator.src_lang = translator.args.lang_dict['English']
translator.tokenizer(
    '多步推理'
).input_ids
# Out:
# [256047, 68500, 251806, 250973, 249418, 2]

# %%
translator.translate_cbs(
    """So it is good to have interpretable multi-step reasoning as output.
And we also think math word problem is a straightforward application to evaluate such reasoning abilities.""",
    src_lang = "English",
    tgt_lang = "Chinese",
    force_words = ['多步推理']
)
# Out:
# ['多步推理']
# '我们也认为数学词题是评估这种推理能力的直接应用. 对于我们来说, 多步推理是很重要的.'
